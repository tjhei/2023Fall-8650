# %%
# see chapter 9 for classes!

class ListItem:
    def __init__(self, x, next):
        self.value = x
        self.next = next
        
class MyStack:
    """ A Stack implemented using a (singly) linked list """
    def __init__(self):
        self.top = None
        
    def push(self, x):
        newitem = ListItem(x, self.top)
        self.top = newitem
        
    def pop(self):
        # remove the top item and return it
        tmp = self.top.value
        self.top = self.top.next
        return tmp
    
    def print(self):
        x = self.top
        while x != None:
            print(x.value, end=" ")
            x = x.next
        print()
    
s = MyStack()
s.push(3)
s.push(4)
#print(s.top.value)
s.push(5)
s.print()

#print(s.top.value, s.top.next.value, s.top.next.next.value)
#print (s, s.top, s.top.value, s.top.next)
#print (s.top.value, s.top.next.value)
#print(s.pop())
#print(s.pop())
# Out:
# 5 4 3
# 3

# %%
import lolviz
lolviz.objviz(s)

# %%
print(s.pop().value)
lolviz.objviz(s)
# Out:
# 4

# %%
# install graphviz and a custom version of lolviz (only needed once). You probably need to do a kernel->restart after that
#!pip install --upgrade --user graphviz
#!ln -fs ~/.local/lib/python3.5/site-packages/graphviz ~/.ipython/
#!wget -O lolviz.py https://raw.githubusercontent.com/tjhei/lolviz/master/lolviz.py
# Out:
# --2022-09-20 02:41:29--  https://raw.githubusercontent.com/tjhei/lolviz/master/lolviz.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33961 (33K) [text/plain]
# Saving to: ‘lolviz.py’
#
# lolviz.py           100%[===================>]  33.17K  --.-KB/s    in 0.006s
#
# 2022-09-20 02:41:29 (5.22 MB/s) - ‘lolviz.py’ saved [33961/33961]
